# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
x=[1,3,5,6,7,8,9,66]
y=[100,59,55,677,334,444,56,33]
plt.plot(x,y,marker='o',c='y')

# %%
plt.scatter(x,y)

# %%
x=np.arange(0,40,0.005)
y=np.cos(x)
plt.scatter(x,y,marker='o',c='g')

# %%
x
# Out:
# array([0])

# %%
x=np.linspace(0,40,200)
y=np.cos(x)
plt.scatter(x,y,marker='o',c='b')

# %%
x
# Out:
# array([ 0.        ,  0.20100503,  0.40201005,  0.60301508,  0.8040201 ,
#         1.00502513,  1.20603015,  1.40703518,  1.6080402 ,  1.80904523,
#         2.01005025,  2.21105528,  2.4120603 ,  2.61306533,  2.81407035,
#         3.01507538,  3.2160804 ,  3.41708543,  3.61809045,  3.81909548,
#         4.0201005 ,  4.22110553,  4.42211055,  4.62311558,  4.8241206 ,
#         5.02512563,  5.22613065,  5.42713568,  5.6281407 ,  5.82914573,
#         6.03015075,  6.23115578,  6.4321608 ,  6.63316583,  6.83417085,
#         7.03517588,  7.2361809 ,  7.43718593,  7.63819095,  7.83919598,
#         8.04020101,  8.24120603,  8.44221106,  8.64321608,  8.84422111,
#         9.04522613,  9.24623116,  9.44723618,  9.64824121,  9.84924623,
#        10.05025126, 10.25125628, 10.45226131, 10.65326633, 10.85427136,
#        11.05527638, 11.25628141, 11.45728643, 11.65829146, 11.85929648,
#        12.06030151, 12.26130653, 12.46231156, 12.66331658, 12.86432161,
# ...

# %%
x=[1,3,5,6,7,8,9,66]
y=[100,59,55,677,334,444,56,33]
plt.bar(x,y)
# Out:
# <BarContainer object of 8 artists>

# %%
plt.pie(x,autopct='%1.1f%%',labels=[1,3,5,6,7,8,9,66],explode=[0,0,0,0,0.5,0,0,0.1])
# Out:
# ([<matplotlib.patches.Wedge at 0x22d5d031940>,
# ...
#  [Text(1.0995076754581865, 0.03290701457949722, '1'),
#   Text(1.0877139078161349, 0.1639464996373907, '3'),
#   Text(1.0178347100223064, 0.41714805893568246, '5'),
#   Text(0.8283785734919077, 0.7237326433010414, '6'),
#   Text(0.7157008470022238, 1.4310039474439964, '7'),
#   Text(0.01645513152038898, 1.0998769152258114, '8'),
#   Text(-0.521255650353199, 0.9686550195889472, '9'),
#   Text(-0.47162968019324897, -1.1034334799890813, '66')],
#  [Text(0.5997314593408289, 0.017949280679725756, '1.0%'),
#   Text(0.5932984951724372, 0.08942536343857672, '2.9%'),
#   Text(0.5551825691030762, 0.22753530487400858, '4.8%'),
#   Text(0.4518428582683132, 0.3947632599823862, '5.7%'),
#   Text(0.49204433231402883, 0.9838152138677474, '6.7%'),
#   Text(0.008975526283848534, 0.5999328628504426, '7.6%'),
#   Text(-0.2843212638290176, 0.5283572834121529, '8.6%'),
#   Text(-0.2751173134460619, -0.6436695299936306, '62.9%')])

# %%
plt.hist(x,bins=10,color='b')
# Out:
# (array([5., 2., 0., 0., 0., 0., 0., 0., 0., 1.]),
#  array([ 1. ,  7.5, 14. , 20.5, 27. , 33.5, 40. , 46.5, 53. , 59.5, 66. ]),
#  <BarContainer object of 10 artists>)

# %%
t=pd.read_csv('customers-100.csv')
sns.stripplot(x="Company",y="City",data=t)
# Out:
# <Axes: xlabel='Company', ylabel='City'>

# %%
sns.swarmplot(x="Company",y="City",data=t)
# Out:
# <Axes: xlabel='Company', ylabel='City'>

# %%
sns.violinplot(x="Company",y="City",data=t)
# Out:
# <Axes: xlabel='Company', ylabel='City'>

# %%
sns.pairplot(data=t)

# %%
tm=np.correlate(x,y)
tm
# Out:
# array([13186])

# %%
sns.heatmap([[tm]], annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 sns.heatmap([[tm]], annot=True)
#
# File M:\MINE\project\Python_START\.venv\Lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)    443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
#     448                       yticklabels, mask)
#     450 # Add the pcolormesh kwargs here
#     451 kwargs["linewidths"] = linewidths
#
# ...
