# %%
import pandas as pd

# %%
m=[40,34,67,46,77]
n=['swea','asif','ak','kir','chand']
x=pd.Series(m,n)

# %%
print(x)
# Out:
# swea     40
# asif     34
# ak       67
# kir      46
# chand    77
# dtype: int64

# %%
x.index
# Out:
# Index(['swea', 'asif', 'ak', 'kir', 'chand'], dtype='object')

# %%
x.values
# Out:
# array([40, 34, 67, 46, 77])

# %%
x["swea":"kir"]
# Out:
# swea    40
# asif    34
# ak      67
# kir     46
# dtype: int64

# %%
x[x>44]
# Out:
# ak       67
# kir      46
# chand    77
# dtype: int64

# %%
x.sort_values()
# Out:
# asif     34
# swea     40
# kir      46
# ak       67
# chand    77
# dtype: int64

# %%
x.sort_index()
# Out:
# ak       67
# asif     34
# chand    77
# kir      46
# swea     40
# dtype: int64

# %%
d={'cars':['BMW','Audi','lambo'],'year':[2000,2001,2002]}
df=pd.DataFrame(d)
print(df)
# Out:
#     cars  year
# 0    BMW  2000
# 1   Audi  2001
# 2  lambo  2002

# %%
d2=pd.DataFrame(d,index=[2000,2001,2002])
d2
# Out:
#        cars  year
# 2000    BMW  2000
# 2001   Audi  2001
# 2002  lambo  2002

# %%
c=pd.read_csv('customers-100.csv')

# %%
c
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
c.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
c.tail()
# Out:
#     Index      Customer Id First Name Last Name                Company  \
# 95     96  cb8E23e48d22Eae       Karl     Greer              Carey LLC
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson  Ware, Burns and Oneal
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra          Schmitt-Jones
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer     Fitzgerald-Harrell
# 99    100  2354a0E336A91A1   Clarence    Haynes     Le, Nash and Cross
#
#                City          Country               Phone 1  \
# 95     East Richard           Guyana   (188)169-1674x58692
# 96     New Bradview        Sri Lanka       +1-846-706-2218
# 97       Ortegaland  Solomon Islands  +1-753-067-8419x7170
# 98  Lake Elijahview            Aruba         (530)311-9786
# 99        Judymouth         Honduras         (753)813-6941
#
#                    Phone 2                           Email Subscription Date  \
# 95    001-841-293-3519x614                hhart@jensen.com        2022-01-30
# ...

# %%
c.sample(6)
# Out:
#     Index      Customer Id First Name Last Name                       Company  \
# 52     53  faCEF517ae7D8eB   Patricia   Goodwin  Christian, Winters and Ellis
# 50     51  Aa20BDe68eAb0e9     Gerald   Hawkins       Phelps, Forbes and Koch
# 37     38  7a1Ee69F4fF4B4D     Jordan       Gay               Glover and Sons
# 46     47  300A40d3ce24bBA   Geoffrey    Guzman                 Short-Wiggins
# 84     85  03A1E62ADdeb31c      Corey      Holt    Mcdonald, Bird and Ramirez
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano                   Vega-Gentry
#
#                  City          Country                Phone 1  \
# 52          Cowanfort        Swaziland     322.549.7139x70040
# 50     New Alberttown           Canada  +1-323-239-1456x96168
# 37       South Walter  Solomon Islands             7208417020
# 46      Zimmermanland       Uzbekistan       975.235.8921x269
# 84         New Glenda             Fiji  001-439-242-4986x7918
# ...

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              100 non-null    int64
#  1   Customer Id        100 non-null    object
#  2   First Name         100 non-null    object
#  3   Last Name          100 non-null    object
#  4   Company            100 non-null    object
#  5   City               100 non-null    object
#  6   Country            100 non-null    object
#  7   Phone 1            100 non-null    object
#  8   Phone 2            100 non-null    object
#  9   Email              100 non-null    object
#  10  Subscription Date  100 non-null    object
#  11  Website            100 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 9.5+ KB

# %%
c.isnull()
# Out:
#     Index  Customer Id  First Name  Last Name  Company   City  Country  \
# 0   False        False       False      False    False  False    False
# 1   False        False       False      False    False  False    False
# 2   False        False       False      False    False  False    False
# 3   False        False       False      False    False  False    False
# 4   False        False       False      False    False  False    False
# ..    ...          ...         ...        ...      ...    ...      ...
# 95  False        False       False      False    False  False    False
# 96  False        False       False      False    False  False    False
# 97  False        False       False      False    False  False    False
# 98  False        False       False      False    False  False    False
# 99  False        False       False      False    False  False    False
#
#     Phone 1  Phone 2  Email  Subscription Date  Website
# 0     False    False  False              False    False
# ...

# %%
c.notnull()
# Out:
#     Index  Customer Id  First Name  Last Name  Company  City  Country  \
# 0    True         True        True       True     True  True     True
# 1    True         True        True       True     True  True     True
# 2    True         True        True       True     True  True     True
# 3    True         True        True       True     True  True     True
# 4    True         True        True       True     True  True     True
# ..    ...          ...         ...        ...      ...   ...      ...
# 95   True         True        True       True     True  True     True
# 96   True         True        True       True     True  True     True
# 97   True         True        True       True     True  True     True
# 98   True         True        True       True     True  True     True
# 99   True         True        True       True     True  True     True
#
#     Phone 1  Phone 2  Email  Subscription Date  Website
# 0      True     True   True               True     True
# ...

# %%
c.describe()
# Out:
#             Index
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000

# %%
c.columns
# Out:
# Index(['Index', 'Customer Id', 'First Name', 'Last Name', 'Company', 'City',
#        'Country', 'Phone 1', 'Phone 2', 'Email', 'Subscription Date',
#        'Website'],
#       dtype='object')

# %%
c[['City','Country']]
# Out:
#                  City                     Country
# 0        East Leonard                       Chile
# 1   East Jimmychester                    Djibouti
# 2       Isabelborough         Antigua and Barbuda
# 3          Bensonview          Dominican Republic
# 4      West Priscilla  Slovakia (Slovak Republic)
# ..                ...                         ...
# 95       East Richard                      Guyana
# 96       New Bradview                   Sri Lanka
# 97         Ortegaland             Solomon Islands
# 98    Lake Elijahview                       Aruba
# 99          Judymouth                    Honduras
#
# [100 rows x 2 columns]

# %%
c.isnull().sum()
# Out:
# Index                0
# Customer Id          0
# First Name           0
# Last Name            0
# Company              0
# City                 0
# Country              0
# Phone 1              0
# Phone 2              0
# Email                0
# Subscription Date    0
# Website              0
# dtype: int64

# %%
c.groupby(by='Country').size()
# Out:
# Country
# Albania                1
# Algeria                1
# Anguilla               1
# Antigua and Barbuda    1
# Aruba                  1
#                       ..
# Uzbekistan             1
# Vietnam                1
# Western Sahara         1
# Yemen                  1
# Zimbabwe               2
# Length: 85, dtype: int64

# %%
c['Phone 1'].agg(['max','min'])
# Out:
# max     981-544-9452
# min    (041)737-3846
# Name: Phone 1, dtype: object

# %%
c.sort_values(by='Phone 1')
# Out:
#     Index      Customer Id First Name   Last Name  \
# 11     12  CEDec94deE6d69B      Jenna      Dodson
# 76     77  BF6a1f9bd1bf8DE   Brittany      Zuniga
# 44     45  30Dfa48fe5Ede78     Rhonda       Frost
# 95     96  cb8E23e48d22Eae       Karl       Greer
# 19     20  0F60FF3DdCd7aB0     Joanna        Kirk
# ..    ...              ...        ...         ...
# 73     74  A3F76Be153Df4a3      Anita      Benson
# 16     17  a5DC21AE3a21eaA   Caroline       Foley
# 30     31  64DCcDFaB9DFd4e       Jack        Tate
# 46     47  300A40d3ce24bBA   Geoffrey      Guzman
# 63     64  FCBdfCEAe20A8Dc      Chloe  Hutchinson
#
#                             Company               City             Country  \
# 11        Hoffman, Reed and Mcclain        East Andrea             Vietnam
# 76                     Mason-Hester      West Reginald     Kyrgyz Republic
# 44  Herrera, Shepherd and Underwood    Lake Lindaburgh              Monaco
# ...
